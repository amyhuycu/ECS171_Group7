# %%
import pandas as pd
import seaborn as sb

#df = pd.read_csv('forestfires.csv')
df_portugal = pd.read_csv('data/Portugal_Dataset.csv')
df_portugal
#sb.heatmap(df.corr(), annot = True, fmt='.1g')
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
# Remove irrelevant columns
# Location may be irrelevant because all are xy coordinates for Montesinho park
columns_to_keep_portugal = [
    'month', 
    'day', 
    'temp', 
    'RH',  # relative humidity
    'wind',  # wind speed
    'rain',  # rain amount
    'area'  # burned area
]

df_portugal = df_portugal[columns_to_keep_portugal]
df_portugal.shape
# Out:
# (517, 7)

# %%
# Removing all missing data
df_portugal = df_portugal.dropna()
print(df_portugal.shape)
# Out:
# (517, 7)

# %%
# Show updated dataset
df_portugal
df_portugal.to_csv('data/Portugal_Dataset_clean.csv')

# %%
import pandas as pd
import seaborn as sb

df_cal_weather = pd.read_csv('data/California_Weather.csv' )

#df_cal_weather

# %%
# Remove irrelevant columns
columns_to_keep_cal_weather = [
    'Stn Id',
    'Stn Name',
    'CIMIS Region', 
    'Date', 
    'Precip (in)',
    'Avg Air Temp (F)',
    'Avg Rel Hum (%)',
    'Avg Wind Speed (mph)',
    'Wind Run (miles)'
]

df_cal_weather = df_cal_weather[columns_to_keep_cal_weather]
df_cal_weather.shape
# Out:
# (128125, 9)

# %%
# Removing all missing data
df_cal_weather = df_cal_weather.dropna()
print(df_cal_weather.shape)
# Out:
# (128112, 9)

# %%
# Show updated dataset
df_cal_weather
df_cal_weather.to_csv('data/California_Weather_clean.csv')

# %%
import pandas as pd
import seaborn as sb

df_cal_fire = pd.read_csv('data/California_Fire_Incidents.csv')
#df_cal_fire

# %%
# Remove irrelevant columns
columns_to_keep_cal_fire = [
    'AcresBurned',
    'ArchiveYear',
    'CalFireIncident',
    'Counties', 
    'Extinguished',
    'Location',  
    'Started'
]

df_cal_fire = df_cal_fire[columns_to_keep_cal_fire]
df_cal_fire.shape
# Out:
# (1636, 7)

# %%
# Removing all missing data
df_cal_fire = df_cal_fire.dropna()
print(df_cal_fire.shape)
# Out:
# (1577, 7)

# %%
# Show updated dataset
df_cal_fire
df_cal_fire.to_csv('data/California_Fire_Incidents_clean.csv')

# %%
# Combine the data from California Weather and California Fire
# Combine based on location and Date

# Split the Date column from California Weather into month / year
df_cal_weather['month'] = df_cal_weather['Date'].str.split('/').str[0].astype('int')
df_cal_weather['year'] = df_cal_weather['Date'].str.split('/').str[2].astype('int')



df_cal_weather
# Out:
#         Stn Id    Stn Name        CIMIS Region       Date  Precip (in)  \
# 0            2  FivePoints  San Joaquin Valley   1/1/2018         0.00
# 1            2  FivePoints  San Joaquin Valley   1/2/2018         0.00
# 2            2  FivePoints  San Joaquin Valley   1/3/2018         0.00
# 3            2  FivePoints  San Joaquin Valley   1/4/2018         0.01
# 4            2  FivePoints  San Joaquin Valley   1/5/2018         0.00
# ...        ...         ...                 ...        ...          ...
# 128120     262      Linden  San Joaquin Valley  9/14/2020         0.00
# 128121     262      Linden  San Joaquin Valley  9/15/2020         0.00
# 128122     262      Linden  San Joaquin Valley  9/16/2020         0.00
# 128123     262      Linden  San Joaquin Valley  9/17/2020         0.00
# 128124     262      Linden  San Joaquin Valley  9/18/2020         0.00
#
#         Avg Air Temp (F)  Avg Rel Hum (%)  Avg Wind Speed (mph)  \
# 0                   47.8             65.0                   3.3
# 1                   47.2             67.0                   3.1
# 2                   49.9             68.0                   4.5
# 3                   56.8             74.0                   5.8
# 4                   59.8             72.0                   4.2
# ...                  ...              ...                   ...
# 128120              66.3             70.0                   3.4
# 128121              66.0             69.0                   2.7
# 128122              68.0             69.0                   3.3
# 128123              70.4             65.0                   3.3
# 128124              68.4             68.0                   4.0
#
#         Wind Run (miles)  month  year
# 0                   78.3      1  2018
# 1                   74.5      1  2018
# 2                  107.5      1  2018
# 3                  140.2      1  2018
# 4                  101.4      1  2018
# ...                  ...    ...   ...
# 128120              81.7      9  2020
# 128121              64.2      9  2020
# 128122              78.2      9  2020
# 128123              78.1      9  2020
# 128124              96.7      9  2020
#
# [128112 rows x 11 columns]

# %%
# Split the Started column from California Weather into month / year
df_cal_fire['year'] = df_cal_fire['Started'].str.split('-').str[0].astype('int')
df_cal_fire['month'] = df_cal_fire['Started'].str.split('-').str[1].astype('int')

df_cal_fire
# Out:
#       AcresBurned  ArchiveYear  CalFireIncident     Counties  \
# 0        257314.0         2013             True     Tuolumne
# 1         30274.0         2013             True  Los Angeles
# 2         27531.0         2013             True    Riverside
# 3         27440.0         2013            False       Placer
# 4         24251.0         2013             True      Ventura
# ...           ...          ...              ...          ...
# 1627         10.0         2019             True    Riverside
# 1629         10.0         2019             True     Siskiyou
# 1630         10.0         2019             True        Butte
# 1631          9.0         2019             True    Riverside
# 1632          2.0         2019             True       Nevada
#
#               Extinguished                                           Location  \
# 0     2013-09-06T18:30:00Z            3 miles east of Groveland along Hwy 120
# 1     2013-06-08T18:30:00Z                            Angeles National Forest
# 2     2013-07-30T18:00:00Z              Hwy 243 & Hwy 74 near Mountain Center
# 3     2013-08-30T08:00:00Z            Deadwood Ridge, northeast of Foresthill
# 4     2013-05-11T06:30:00Z  Southbound Highway 101 at Camarillo Springs Ro...
# ...                    ...                                                ...
# 1627  2019-09-10T10:45:00Z           Bailey Road and Terwilliger Road in Anza
# 1629  2019-06-21T14:23:00Z         Deer Run Road, east of Iron Gate Reservoir
# 1630  2019-05-08T08:47:00Z  Off Hamilton Nord Cana Hwy & Cana Hwy, northea...
# 1631  2019-10-10T18:11:00Z  Eagle Canyon Rd. and Cajalco Rd., southwest of...
# 1632  2019-06-28T17:33:00Z  Off of  Long Point Road and Old Mill Road, Sou...
#
#                    Started  year  month
# 0     2013-08-17T15:25:00Z  2013      8
# 1     2013-05-30T15:28:00Z  2013      5
# 2     2013-07-15T13:43:00Z  2013      7
# 3     2013-08-10T16:30:00Z  2013      8
# 4     2013-05-02T07:01:00Z  2013      5
# ...                    ...   ...    ...
# 1627  2019-09-10T10:43:58Z  2019      9
# 1629  2019-06-16T20:33:00Z  2019      6
# 1630  2019-04-30T12:20:00Z  2019      4
# 1631  2019-10-10T12:08:00Z  2019     10
# 1632  2019-06-28T15:03:04Z  2019      6
#
# [1577 rows x 9 columns]

# %%
# Get the unique Regions/Counties of weather/fire and use 'str.replace()' to merge identical values

# Cleaning up Cal_Fire Counties to match Cal_weather Regions Choices

# San Francisco Bay
sf_bay = ['Alameda', 'Amador', 'Marin', 'Napa', 'San Mateo', 'Santa Clara', 'Sonoma']
# ?
cent_cal = ['Fresno', 'Monterey','San Joaquin Valley']
# Sacramento Valley
sac_valley = ['Butte', 'Sacramento Valley', 'Sutter', 'Yuba']
# North Coast Valleys
north_coast = ['Humboldt','Mendocino']
# ?
in_so_cal = ['Kern', 'San Bernardino']
# Los Angeles Basin
la_basin = ['Los Angeles']
# ?
great_basin = ['Modoc']
# Sierra Foothill
sierra_nv = ['Nevada', 'Sierra', 'State of Nevada']
# South Coast Valleys
so_coast = ['Orange', 'San Diego']
# Central Coast Valleys
cent_coast = ['San Luis Obispo', 'Santa Barbara', 'Santa Cruz']
# ?
shasta_cas = [ 'Shasta', 'Trinity']

# Unknown:
# Alpine, Calaveras, Colusa, Contra Costa, Del Norte, El Dorado, Glenn, Inyo, Kings, Lake, Lassen, Madera
# Mariposa, Merced, Mexico, Mono, Placer, Plumas, Riverside, San Benito, Siskiyou, Solano, Stanislaus
# State of Oregon, Tehama, Tulare, Tuolumne, Ventura, Yolo,


df_cal_fire['Counties'] = df_cal_fire['Counties'].str.replace('Alameda', 'San Francisco Bay')

regions_list = {'SanFranciscoBay': sf_bay, 'CentralCal': cent_cal, 'SacramentoValley': sac_valley, 
                'NorthCoastValleys': north_coast, 'InlandSoCal': in_so_cal, 'LosAngelesBasin': la_basin, 
                'GreatBasin': great_basin, 'SierraFoothill': sierra_nv, 'SouthCoastValleys': so_coast, 
                'CentralCoastValleys': cent_coast, 'ShastaCascade': shasta_cas}

for region_name in regions_list:
    for county in regions_list[region_name]:
        # FIXME
        df_cal_fire['Counties'] = df_cal_fire['Counties'].str.replace(county, region_name)

unique_regions = (df_cal_weather['CIMIS Region'].unique())
print(sorted(unique_regions))
unique_counties = (df_cal_fire['Counties'].unique())
print(sorted(unique_counties))
# Out:
# ['Bishop', 'Central Coast Valleys', 'Eastern Sierra Basin & Range', 'Imperial/Coachella Valley', 'Los Angeles Basin', 'Monterey Bay', 'North Coast Valleys', 'Northeast Plateau', 'Sacramento Valley', 'San Bernardino', 'San Francisco Bay', 'San Joaquin Valley', 'Sierra Foothill', 'South Coast Valleys']
# ['Alpine', 'Calaveras', 'CentralCal', 'CentralCoastValleys', 'Colusa', 'Contra Costa', 'Del Norte', 'El Dorado', 'Glenn', 'GreatBasin', 'InlandSoCal', 'Inyo', 'Kings', 'Lake', 'Lassen', 'LosAngelesBasin', 'Madera', 'Mariposa', 'Merced', 'Mexico', 'Mono', 'NorthCoastValleys', 'Placer', 'Plumas', 'Riverside', 'Sacramento', 'SacramentoValley', 'San Benito', 'San Francisco Bay', 'San Joaquin', 'SanFranciscoBay', 'ShastaCascade', 'SierraFoothill', 'SierraFoothillFoothill', 'Siskiyou', 'Solano', 'SouthCoastValleys', 'Stanislaus', 'State of Oregon', 'State of SierraFoothillFoothill', 'Tehama', 'Tulare', 'Tuolumne', 'Ventura', 'Yolo']

# %%
#import CIMIS station data, drop Stn Name(duplicate with CA weather) and Status(irrelevant)
df_cimis = pd.read_csv('data/cimis_stations.csv', names=['Stn Id', 'Stn Name', 'Counties', 'Status'])
df_cimis = df_cimis[['Stn Id','Counties']]

#combine CIMIS data with CA weather data (CIMIS data has counties that are in the same format as in CA fire)
df_weather_with_counties = pd.merge(df_cal_weather,df_cimis, on = ['Stn Id'])

#combine matching entries of CA fire and CA weather by County, month, and year
df_CA_merged = pd.merge(df_cal_fire,df_weather_with_counties, how = 'inner', on = ['Counties','month','year'])

df_CA_merged
# Out:
#        AcresBurned  ArchiveYear  CalFireIncident    Counties  \
# 0         410203.0         2018             True      Colusa
# 1         410203.0         2018             True      Colusa
# 2         410203.0         2018             True      Colusa
# 3         410203.0         2018             True      Colusa
# 4         410203.0         2018             True      Colusa
# ...            ...          ...              ...         ...
# 28690         11.0         2019             True  Stanislaus
# 28691         11.0         2019             True  Stanislaus
# 28692         11.0         2019             True  Stanislaus
# 28693         11.0         2019             True  Stanislaus
# 28694         11.0         2019             True  Stanislaus
#
#                Extinguished  \
# 0      2019-01-04T09:33:00Z
# 1      2019-01-04T09:33:00Z
# 2      2019-01-04T09:33:00Z
# 3      2019-01-04T09:33:00Z
# 4      2019-01-04T09:33:00Z
# ...                     ...
# 28690  2019-09-13T21:43:00Z
# 28691  2019-09-13T21:43:00Z
# 28692  2019-09-13T21:43:00Z
# 28693  2019-09-13T21:43:00Z
# 28694  2019-09-13T21:43:00Z
#
#                                                 Location  \
# 0      off Highway 20 near Potter Valley, northeast o...
# 1      off Highway 20 near Potter Valley, northeast o...
# 2      off Highway 20 near Potter Valley, northeast o...
# 3      off Highway 20 near Potter Valley, northeast o...
# 4      off Highway 20 near Potter Valley, northeast o...
# ...                                                  ...
# 28690                                      Knights Ferry
# 28691                                      Knights Ferry
# 28692                                      Knights Ferry
# 28693                                      Knights Ferry
# 28694                                      Knights Ferry
#
#                     Started  year  month  Stn Id   Stn Name  \
# 0      2018-07-27T12:05:00Z  2018      7     250   Williams
# 1      2018-07-27T12:05:00Z  2018      7     250   Williams
# 2      2018-07-27T12:05:00Z  2018      7     250   Williams
# 3      2018-07-27T12:05:00Z  2018      7     250   Williams
# 4      2018-07-27T12:05:00Z  2018      7     250   Williams
# ...                     ...   ...    ...     ...        ...
# 28690  2019-09-13T20:00:29Z  2019      9     206  Denair II
# 28691  2019-09-13T20:00:29Z  2019      9     206  Denair II
# 28692  2019-09-13T20:00:29Z  2019      9     206  Denair II
# 28693  2019-09-13T20:00:29Z  2019      9     206  Denair II
# 28694  2019-09-13T20:00:29Z  2019      9     206  Denair II
#
#              CIMIS Region       Date  Precip (in)  Avg Air Temp (F)  \
# 0       Sacramento Valley   7/1/2018          0.0              82.7
# 1       Sacramento Valley   7/2/2018          0.0              75.8
# 2       Sacramento Valley   7/3/2018          0.0              73.9
# 3       Sacramento Valley   7/4/2018          0.0              67.6
# 4       Sacramento Valley   7/5/2018          0.0              71.0
# ...                   ...        ...          ...               ...
# 28690  San Joaquin Valley  9/26/2019          0.0              74.8
# 28691  San Joaquin Valley  9/27/2019          0.0              67.9
# 28692  San Joaquin Valley  9/28/2019          0.0              61.1
# 28693  San Joaquin Valley  9/29/2019          0.0              57.9
# 28694  San Joaquin Valley  9/30/2019          0.0              56.4
#
#        Avg Rel Hum (%)  Avg Wind Speed (mph)  Wind Run (miles)
# 0                 52.0                   4.8             114.4
# 1                 67.0                   5.0             119.4
# 2                 63.0                   5.0             119.9
# 3                 72.0                   5.6             135.6
# 4                 65.0                   3.8              90.6
# ...                ...                   ...               ...
# 28690             58.0                   5.3             126.7
# 28691             71.0                   5.0             121.0
# 28692             62.0                   4.4             106.8
# 28693             56.0                   5.0             119.3
# 28694             60.0                   4.8             115.3
#
# [28695 rows x 18 columns]

# %%
dummy_df = df_CA_merged._get_numeric_data()
dummy_df = dummy_df.drop('CalFireIncident', 1)
dummy_df.dtypes
# Out:
# AcresBurned             float64
# ArchiveYear               int64
# year                      int32
# month                     int32
# Stn Id                    int64
# Precip (in)             float64
# Avg Air Temp (F)        float64
# Avg Rel Hum (%)         float64
# Avg Wind Speed (mph)    float64
# Wind Run (miles)        float64
# dtype: object

# %% [markdown]
# # Testing the dummy model

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
ANN = Sequential()
ANN.add(Dense(50, input_dim=9, activation='sigmoid'))
ANN.add(Dense(1, activation='relu'))
ANN.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer='adam', metrics=[tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

# %%
X = dummy_df.drop(['AcresBurned'], 1)
Y = dummy_df['AcresBurned']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
ANN.fit(X_train, Y_train, batch_size=100, epochs=10)
# Out:
# Epoch 1/10
# 201/201 [==============================] - 0s 537us/step - loss: 259329200.0000 - mean_squared_error: 259329200.0000 - mean_absolute_error: 1668.0619
# Epoch 2/10
# 201/201 [==============================] - 0s 638us/step - loss: 259314992.0000 - mean_squared_error: 259314992.0000 - mean_absolute_error: 1663.8566
# Epoch 3/10
# 201/201 [==============================] - 0s 622us/step - loss: 259301104.0000 - mean_squared_error: 259301088.0000 - mean_absolute_error: 1660.0740
# Epoch 4/10
# 201/201 [==============================] - 0s 537us/step - loss: 259287504.0000 - mean_squared_error: 259287504.0000 - mean_absolute_error: 1656.9458
# Epoch 5/10
# 201/201 [==============================] - 0s 468us/step - loss: 259273808.0000 - mean_squared_error: 259273808.0000 - mean_absolute_error: 1654.5223
# Epoch 6/10
# 201/201 [==============================] - 0s 468us/step - loss: 259260096.0000 - mean_squared_error: 259260096.0000 - mean_absolute_error: 1652.5288
# Epoch 7/10
# 201/201 [==============================] - 0s 552us/step - loss: 259246352.0000 - mean_squared_error: 259246352.0000 - mean_absolute_error: 1651.0214
# Epoch 8/10
# 201/201 [==============================] - 0s 557us/step - loss: 259232544.0000 - mean_squared_error: 259232544.0000 - mean_absolute_error: 1649.8459
# Epoch 9/10
# 201/201 [==============================] - 0s 532us/step - loss: 259218736.0000 - mean_squared_error: 259218736.0000 - mean_absolute_error: 1649.0310
# Epoch 10/10
# 201/201 [==============================] - 0s 522us/step - loss: 259205104.0000 - mean_squared_error: 259205104.0000 - mean_absolute_error: 1648.4504

# %%
Y_predict_train = ANN.predict(X_train)

print('Train Accuracy:', metrics.mean_squared_error(Y_train, Y_predict_train))
# Out:
# Train Accuracy: 259198132.44100553
